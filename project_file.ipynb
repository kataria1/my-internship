# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# first load the csv1 file

# %%
df1=pd.read_csv("csv1.csv")
df1
# Out:
#     serial                                             movies  \
# 0      1.0                Spider-Man: Across the Spider-Verse
# 1      2.0                                    The Dark Knight
# 2      3.0      The Lord of the Rings: The Return of the King
# 3      4.0                                          Inception
# 4      5.0  The Lord of the Rings: The Fellowship of the Ring
# 5      6.0              The Lord of the Rings: The Two Towers
# 6      7.0                                         The Matrix
# 7      8.0     Star Wars: Episode V - The Empire Strikes Back
# 8      9.0                                    Soorarai Pottru
# 9     10.0                 Star Wars: Episode IV - A New Hope
# 10    11.0                         Terminator 2: Judgment Day
# 11    12.0                                      Seven Samurai
# 12    13.0                                           Harakiri
# 13    14.0                                         Sita Ramam
# ...

# %% [markdown]
# load the csv 2 file

# %%
df2=pd.read_csv("csv2.csv")
df2
# Out:
#                                                movies  \
# 0                 Spider-Man: Across the Spider-Verse
# 1                                     The Dark Knight
# 2       The Lord of the Rings: The Return of the King
# 3                                           Inception
# 4   The Lord of the Rings: The Fellowship of the Ring
# 5               The Lord of the Rings: The Two Towers
# 6                                          The Matrix
# 7      Star Wars: Episode V - The Empire Strikes Back
# 8                                     Soorarai Pottru
# 9                  Star Wars: Episode IV - A New Hope
# 10                         Terminator 2: Judgment Day
# 11                                      Seven Samurai
# 12                                           Harakiri
# 13                                         Sita Ramam
# 14                             Léon: The Professional
# 15                                          Gladiator
# ...

# %% [markdown]
# now merge both csv1 and csv 2 file

# %%
df=pd.merge(df1,df2,on='movies')
df
# Out:
#     serial                                             movies  \
# 0      1.0                Spider-Man: Across the Spider-Verse
# 1      2.0                                    The Dark Knight
# 2      3.0      The Lord of the Rings: The Return of the King
# 3      4.0                                          Inception
# 4      5.0  The Lord of the Rings: The Fellowship of the Ring
# 5      6.0              The Lord of the Rings: The Two Towers
# 6      7.0                                         The Matrix
# 7      8.0     Star Wars: Episode V - The Empire Strikes Back
# 8      9.0                                    Soorarai Pottru
# 9     10.0                 Star Wars: Episode IV - A New Hope
# 10    11.0                         Terminator 2: Judgment Day
# 11    12.0                                      Seven Samurai
# 12    13.0                                           Harakiri
# 13    14.0                                         Sita Ramam
# ...

# %%
df.head()
# Out:
#    serial                                             movies  \
# 0     1.0                Spider-Man: Across the Spider-Verse
# 1     2.0                                    The Dark Knight
# 2     3.0      The Lord of the Rings: The Return of the King
# 3     4.0                                          Inception
# 4     5.0  The Lord of the Rings: The Fellowship of the Ring
#
#        director_names duration    year  rating  metascore  \
# 0  Joaquim Dos Santos  140 min  (2023)     9.1       86.0
# 1   Christopher Nolan  152 min  (2008)     9.0       84.0
# 2       Peter Jackson  201 min  (2003)     9.0       94.0
# 3   Christopher Nolan  148 min  (2010)     8.8       74.0
# 4       Peter Jackson  178 min  (2001)     8.8       92.0
#
#                                           stars_list     vote  \
# 0  Shameik Moore, Hailee Steinfeld, Brian Tyree H...    76781
# 1  Christian Bale, Heath Ledger, Aaron Eckhart, M...  2721460
# ...

# %%
df.tail()
# Out:
#     serial                               movies  director_names duration  \
# 45    46.0                              Warrior  Gavin O'Connor  140 min
# 46    47.0  Demon Slayer the Movie: Mugen Train  Haruo Sotozaki  117 min
# 47    48.0                                  Ran  Akira Kurosawa  162 min
# 48    49.0                   Gangs of Wasseypur  Anurag Kashyap  321 min
# 49    50.0                         Vikram Vedha         Gayatri  147 min
#
#       year  rating  metascore  \
# 45  (2011)     8.2        NaN
# 46  (2020)     8.2        NaN
# 47  (1985)     8.2        NaN
# 48  (2012)     8.2        NaN
# 49  (2017)     8.2        NaN
#
#                                            stars_list    vote  \
# 45  Tom Hardy, Nick Nolte, Joel Edgerton, Jennifer...  482106
# 46  Natsuki Hanae, Akari Kitô, Yoshitsugu Matsuoka...   64593
# 47  Tatsuya Nakadai, Akira Terao, Jinpachi Nezu, D...  129292
# 48  Manoj Bajpayee, Nawazuddin Siddiqui, Tigmanshu...   99419
# ...

# %%
df.shape
# Out:
# (50, 13)

# %% [markdown]
# there are 50 rows and 13 columns

# %%
df.dtypes
# Out:
# serial            float64
# movies             object
# director_names     object
# duration           object
# year               object
# rating            float64
# metascore         float64
# stars_list         object
# vote                int64
# genre_list         object
# gross_list        float64
# popularity        float64
# certificate        object
# dtype: object

# %% [markdown]
# year and duration variable are string data type so we need to convert it into int data type

# %%
df['duration']=df['duration'].str.replace('min','')
df['duration']=df['duration'].astype('int')

# %%
df['year']=df['year'].str.replace('(','').str.replace(')','').astype(int)

# %%
df.dtypes
# Out:
# serial            float64
# movies             object
# director_names     object
# duration            int32
# year                int32
# rating            float64
# metascore         float64
# stars_list         object
# vote                int64
# genre_list         object
# gross_list        float64
# popularity        float64
# certificate        object
# dtype: object

# %% [markdown]
# now each columns have their correct data type

# %%
df.isnull().sum()
# Out:
# serial             0
# movies             0
# director_names     0
# duration           0
# year               0
# rating             0
# metascore         12
# stars_list         0
# vote               0
# genre_list         0
# gross_list        13
# popularity         0
# certificate        0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# metascore ,gross_list columns have null values

# %%
df['metascore']=df['metascore'].fillna(np.mean(df['metascore']))

# %%
df['gross_list']=df['gross_list'].fillna(np.mean(df['gross_list']))

# %%
df.isnull().sum()
# Out:
# serial            0
# movies            0
# director_names    0
# duration          0
# year              0
# rating            0
# metascore         0
# stars_list        0
# vote              0
# genre_list        0
# gross_list        0
# popularity        0
# certificate       0
# dtype: int64

# %% [markdown]
# now there is no null values present in dataframe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   serial          50 non-null     float64
#  1   movies          50 non-null     object
#  2   director_names  50 non-null     object
#  3   duration        50 non-null     int32
#  4   year            50 non-null     int32
#  5   rating          50 non-null     float64
#  6   metascore       50 non-null     float64
#  7   stars_list      50 non-null     object
#  8   vote            50 non-null     int64
#  9   genre_list      50 non-null     object
#  10  gross_list      50 non-null     float64
#  11  popularity      50 non-null     float64
#  12  certificate     50 non-null     object
# dtypes: float64(5), int32(2), int64(1), object(5)
# memory usage: 5.1+ KB

# %% [markdown]
# visualization

# %%
df
# Out:
#     serial                                             movies  \
# 0      1.0                Spider-Man: Across the Spider-Verse
# 1      2.0                                    The Dark Knight
# 2      3.0      The Lord of the Rings: The Return of the King
# 3      4.0                                          Inception
# 4      5.0  The Lord of the Rings: The Fellowship of the Ring
# 5      6.0              The Lord of the Rings: The Two Towers
# 6      7.0                                         The Matrix
# 7      8.0     Star Wars: Episode V - The Empire Strikes Back
# 8      9.0                                    Soorarai Pottru
# 9     10.0                 Star Wars: Episode IV - A New Hope
# 10    11.0                         Terminator 2: Judgment Day
# 11    12.0                                      Seven Samurai
# 12    13.0                                           Harakiri
# 13    14.0                                         Sita Ramam
# ...

# %%
plt.scatter(df['duration'],df['rating'])
plt.show()

# %% [markdown]
# maximum movies are between 110 min - 180 min and only 1 movie duration is more than 300 min

# %%
plt.bar(df['year'], df['gross_list'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# the maximum gross collection earned by movies in between 1992-1996 and minimum earned in 1970

# %%
sns.countplot(x='genre_list',data=df)
df['genre_list'].value_counts()
# Out:
# Action, Crime, Drama            8
# Action, Adventure, Drama        6
# Animation, Action, Adventure    4
# Action, Adventure, Sci-Fi       4
# Action, Adventure, Fantasy      4
# Action, Drama                   4
# Action, Drama, Mystery          3
# Action, Drama, War              2
# Action, Sci-Fi                  2
# Action, Adventure               2
# Action, Biography, Drama        2
# Action, Drama, Sport            1
# Action, Drama, Sci-Fi           1
# Action, Thriller                1
# Action, Adventure, Crime        1
# Action, Adventure, Comedy       1
# Action, Crime, Thriller         1
# Action, Adventure, Mystery      1
# Action, Drama, Thriller         1
# Action, Comedy, Crime           1
# Name: genre_list, dtype: int64

# %% [markdown]
# (Action, Crime, Drama) genre are maximum movies

# %%
sns.countplot(x='certificate',data=df)
df['certificate'].value_counts()
# Out:
# PG-13        16
# R            13
# Not Rated    10
# PG            6
# TV-MA         1
# U             1
# Approved      1
# UA            1
# TV-14         1
# Name: certificate, dtype: int64

# %% [markdown]
# PG-13 cerificate is alloted to maximum movies

# %%
plt.bar(df['year'], df['vote'])
plt.xlabel('Year')
plt.ylabel('Vote')
plt.show()

# %% [markdown]
# the maximum votes earned in year between 2006-2008

# %%
sns.countplot(x='rating',data=df)
df['rating'].value_counts()
# Out:
# 8.2    14
# 8.3    11
# 8.4     9
# 8.6     5
# 8.8     3
# 8.7     3
# 9.0     2
# 8.5     2
# 9.1     1
# Name: rating, dtype: int64

# %% [markdown]
# 8.2 rating is achived by maximum movies and 9.1 is achived by only one movie

# %%
plt.hist(df['metascore'], bins=10,edgecolor='red')
# Out:
# (array([ 4.,  4.,  5.,  5., 17.,  1.,  7.,  2.,  2.,  3.]),
#  array([62. , 65.6, 69.2, 72.8, 76.4, 80. , 83.6, 87.2, 90.8, 94.4, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['vote'], df['rating'])

# %%
plt.boxplot(df['gross_list'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x240bdd57550>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x240bdd576d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x240bdd57af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x240bdd4a520>],
#  'fliers': [<matplotlib.lines.Line2D at 0x240bdd4a6a0>],
#  'means': []}

# %% [markdown]
# encoding the data

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#     serial  movies  director_names  duration  year  rating  metascore  \
# 0      1.0      32              16       140  2023     9.1  86.000000
# 1      2.0      39               5       152  2008     9.0  84.000000
# 2      3.0      42              27       201  2003     9.0  94.000000
# 3      4.0      14               5       148  2010     8.8  74.000000
# 4      5.0      41              27       178  2001     8.8  92.000000
# 5      6.0      43              27       179  2002     8.8  87.000000
# 6      7.0      44              20       136  1999     8.7  73.000000
# 7      8.0      36              12       124  1980     8.7  82.000000
# 8      9.0      31              36       153  2020     8.7  90.000000
# 9     10.0      35               8       121  1977     8.6  75.000000
# 10    11.0      38              13       137  1991     8.6  98.000000
# 11    12.0      28               0       207  1954     8.6  85.000000
# ...

# %% [markdown]
# all the variables changed to numerical

# %%
df.describe().T
# Out:
#                 count           mean            std       min         25%  \
# serial           50.0      25.500000      14.577380      1.00      13.250
# movies           50.0      24.500000      14.577380      0.00      12.250
# director_names   50.0      18.320000      11.810476      0.00       7.250
# duration         50.0     148.360000      33.732900    101.00     131.250
# year             50.0    2003.780000      17.939001   1954.00    1993.250
# rating           50.0       8.426000       0.239736      8.20       8.200
# metascore        50.0      78.526316       8.796421     62.00      72.250
# stars_list       50.0      24.060000      14.148498      0.00      12.250
# vote             50.0  790070.360000  696815.110096  31233.00  125980.000
# genre_list       50.0       9.040000       5.495675      0.00       4.000
# gross_list       50.0     236.743784     202.509151      0.27      73.635
# popularity       50.0       8.426000       0.239736      8.20       8.200
# ...

# %% [raw]
# 1).there is gap between 75% and max data so their is chance of having outliers
# 2).duration,vote columns have high mean values than respective median so the skewed data is also there
# 3).stardard deviation values are also high in many columns,so data range is also high

# %%
dfc=df.corr()
dfc
# Out:
#                   serial    movies  director_names  duration      year  \
# serial          1.000000 -0.226891        0.003201  0.016393  0.190851
# movies         -0.226891  1.000000       -0.098031 -0.005976  0.006516
# director_names  0.003201 -0.098031        1.000000 -0.230245  0.135483
# duration        0.016393 -0.005976       -0.230245  1.000000  0.105996
# year            0.190851  0.006516        0.135483  0.105996  1.000000
# rating         -0.917125  0.322060       -0.036875  0.103800 -0.107312
# metascore      -0.229341  0.130012       -0.063243  0.091818  0.089272
# stars_list      0.112357  0.107509       -0.008544  0.015048  0.040015
# vote           -0.485142  0.208606       -0.112677 -0.066969 -0.190027
# genre_list      0.122532  0.132721       -0.280667 -0.158822  0.102559
# gross_list     -0.197619 -0.179539       -0.011217 -0.027400 -0.217480
# popularity     -0.917125  0.322060       -0.036875  0.103800 -0.107312
# ...

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [raw]
# rating and popularity column are high positively correlated with votes variable
# popularity and rating variable highly correlated and their will be multicolliretity while training the model

# %%
df.skew()
# Out:
# serial            0.000000
# movies            0.000000
# director_names    0.038234
# duration          2.885339
# year             -1.003570
# rating            1.151693
# metascore         0.381478
# stars_list       -0.013050
# vote              0.805190
# genre_list        0.317938
# gross_list        1.359984
# popularity        1.151693
# certificate       0.750901
# dtype: float64

# %%
sns.distplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='Density'>

# %%
sns.distplot(df['duration'])
# Out:
# <AxesSubplot:xlabel='duration', ylabel='Density'>

# %%
sns.distplot(df['vote'])
# Out:
# <AxesSubplot:xlabel='vote', ylabel='Density'>

# %%
sns.distplot(df['certificate'])
# Out:
# <AxesSubplot:xlabel='certificate', ylabel='Density'>

# %%
df['duration'] = np.log1p(df['duration'])

# %%
df['rating'] = np.log1p(df['rating'])

# %%
df.skew()
# Out:
# serial            0.000000
# movies            0.000000
# director_names    0.038234
# duration          1.420614
# year             -1.003570
# rating            1.107143
# metascore         0.381478
# stars_list       -0.013050
# vote              0.805190
# genre_list        0.317938
# gross_list        1.359984
# popularity        1.151693
# certificate       0.750901
# dtype: float64

# %%
df.drop('popularity',axis=1,inplace =True)

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
print(np.where(z>3))
# Out:
# (array([14, 34, 48], dtype=int64), array([10, 11,  3], dtype=int64))

# %%
dfn=df[(z<3).all(axis=1)]
dfn.shape
# Out:
# (47, 12)

# %%
df=dfn

# %%
df.shape
# Out:
# (47, 12)

# %% [markdown]
# outliers  are removed

# %% [markdown]
# Split the data

# %%
x=df.drop('vote',axis=1)
y=df['vote']

# %%
x.shape
# Out:
# (47, 11)

# %%
y.shape
# Out:
# (47,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.preprocessing import StandardScaler

# %%
st=StandardScaler()
x=st.fit_transform(x)
x
# Out:
# array([[-1.67650301e+00,  5.29841571e-01, -2.12224037e-01,
#         -1.55729566e-01,  1.08606317e+00,  2.72020385e+00,
#          8.48857123e-01,  6.77548531e-01,  1.77571070e+00,
#          1.67755218e+00, -6.26118402e-01],
#        [-1.60671059e+00,  1.01812694e+00, -1.14205308e+00,
#          3.92731316e-01,  2.53808240e-01,  2.32655189e+00,
#          6.22309182e-01, -1.19567388e+00, -7.58850726e-03,
#          8.18465293e-01,  9.16270833e-02],
#        [-1.53691818e+00,  1.22739210e+00,  7.17605008e-01,
#          2.25833412e+00, -2.36100689e-02,  2.32655189e+00,
#          1.75504889e+00, -6.40645016e-01, -1.07756803e+00,
#          3.51906865e-01,  9.16270833e-02],
#        [-1.46712576e+00, -7.25749378e-01, -1.14205308e+00,
#          2.14842420e-01,  3.64775564e-01,  1.52729854e+00,
#         -5.10430523e-01, -8.56161542e-02, -5.42578269e-01,
#          4.77533480e-01,  9.16270833e-02],
#        [-1.39733334e+00,  1.15763704e+00,  7.17605008e-01,
# ...

# %%
x=pd.DataFrame(x)
x
# Out:
#           0         1         2         3         4         5         6   \
# 0  -1.676503  0.529842 -0.212224 -0.155730  1.086063  2.720204  0.848857
# 1  -1.606711  1.018127 -1.142053  0.392731  0.253808  2.326552  0.622309
# 2  -1.536918  1.227392  0.717605  2.258334 -0.023610  2.326552  1.755049
# 3  -1.467126 -0.725749 -1.142053  0.214842  0.364776  1.527299 -0.510431
# 4  -1.397333  1.157637  0.717605  1.446623 -0.134577  1.527299  1.528501
# 5  -1.327541  1.297147  0.717605  1.484032 -0.079094  1.527299  0.962131
# 6  -1.257748  1.366902  0.125896 -0.348978 -0.245545  1.121534 -0.623704
# 7  -1.187956  0.808862 -0.550344 -0.964515 -1.299734  1.121534  0.395761
# 8  -1.118164  0.460087  1.478374  0.436477  0.919612  1.121534  1.301953
# 9  -1.048371  0.739107 -0.888463 -1.127638 -1.466185  0.711565 -0.397157
# 10 -0.978579  0.948372 -0.465814 -0.300142 -0.689414  0.711565  2.208145
# 11 -0.908786  0.250821 -1.564703  2.454882 -2.742309  0.711565  0.735583
# ...

# %%
lr=LinearRegression()

# %%
for i in range(0,60):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    
    print('at random state',i)
    print('the training accuracy is',r2_score(y_train,pred_train))
    print('the testing accuracy is',r2_score(y_test,pred_test))
# Out:
# at random state 0
# the training accuracy is 0.3795651155376586
# the testing accuracy is 0.5391709435079446
# at random state 1
# the training accuracy is 0.4421536811861084
# the testing accuracy is 0.22848667195367067
# at random state 2
# the training accuracy is 0.6594173186400307
# the testing accuracy is -3.0550420838832713
# at random state 3
# the training accuracy is 0.39997498091211825
# the testing accuracy is 0.5028379956325091
# at random state 4
# the training accuracy is 0.4379709675258354
# the testing accuracy is 0.056683470529551694
# at random state 5
# the training accuracy is 0.45050478654856885
# the testing accuracy is 0.08508829669120599
# at random state 6
# the training accuracy is 0.5445637605067126
# the testing accuracy is -0.8437225959783223
# at random state 7
# the training accuracy is 0.6166896647236597
# the testing accuracy is -0.4535603675844526
# at random state 8
# the training accuracy is 0.5947520246217388
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=57)

# %%
lr.fit(x_train,y_train)
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
print(r2_score(y_train,pred_train))
print(r2_score(y_test,pred_test))
# Out:
# 0.41336792812016254
# 0.39002079626410835

# %% [markdown]
# at this there is not very much difference b/w training and testing model

# %%
from sklearn.model_selection import GridSearchCV
from  sklearn.linear_model import Lasso,Ridge

# %%
ls=Lasso()
values={'alpha':[0.1,0.001,0.0001]}

# %%
gr=GridSearchCV(ls,values)
gr.fit(x,y)
print(gr)
# Out:
# GridSearchCV(estimator=Lasso(), param_grid={'alpha': [0.1, 0.001, 0.0001]})

# %%
print(gr.best_params_)
# Out:
# {'alpha': 0.1}

# %%
ls=Lasso(alpha=0.1)
ls.fit(x_train,y_train)
pred_test=ls.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.39002114561650414

# %%
rd=Ridge()
values={'alpha':[0.1,0.001,0.0001,1]}

# %%
gr=GridSearchCV(rd,values)
gr.fit(x,y)
print(gr)
# Out:
# GridSearchCV(estimator=Ridge(), param_grid={'alpha': [0.1, 0.001, 0.0001, 1]})

# %%
print(gr.best_params_)
# Out:
# {'alpha': 1}

# %%
rd=Ridge(alpha=1)
rd.fit(x_train,y_train)
pred_test=rd.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.4094243311450154

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_train=dtr.predict(x_train)
pred_test=dtr.predict(x_test)
print(r2_score(y_train,pred_train))
print(r2_score(y_test,pred_test))
# Out:
# 1.0
# 0.5224775298224976

# %%
from sklearn.ensemble import RandomForestRegressor 
rf=RandomForestRegressor(n_estimators=200,random_state=53)
rf.fit(x_train,y_train)
pred_train=rf.predict(x_train)
pred_test=rf.predict(x_test)
print(r2_score(y_test,pred_test))
# Out:
# 0.5428955155724223

# %% [markdown]
# as the random forest we are getting high r2_score so it is our final model

# %%
import pickle
cap='caps.pkl'
pickle.dump(rf,open(cap,'wb'))

# %% [markdown]
# -----------------------------------------end---------------------------------------------------------------------
